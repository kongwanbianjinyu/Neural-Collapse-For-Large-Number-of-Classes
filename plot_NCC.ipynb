# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
import os
save_path = "./images/NCC"
os.mkdir(save_path)

# %%
resnet18_K100_train = [27.67, 44.922000000000004, 61.364, 69.396, 73.762, 77.39, 80.464, 83.038, 85.404, 88.426, 90.41, 92.408, 94.998, 97.304, 98.386, 99.11999999999999, 99.614, 99.802, 99.824, 99.848]
resnet18_K100_test = [24.79, 40.65, 53.449999999999996, 56.75, 59.84, 60.46, 60.79, 61.29, 61.7, 63.12, 61.980000000000004, 62.56, 63.44, 64.05, 65.3, 65.41, 65.72, 66.06, 66.42, 66.47999999999999]

resnet18_K100_train_tau1 = [24.52, 29.802, 33.64, 34.744, 36.516, 38.428000000000004, 39.172000000000004, 40.164, 42.934, 43.368, 44.402, 46.042, 45.102, 47.854, 47.839999999999996, 49.754, 51.08200000000001, 51.30200000000001, 51.726000000000006, 51.656]
resnet18_K100_test_tau1 = [23.3, 28.12, 32.24, 32.129999999999995, 33.01, 35.07, 35.35, 34.5, 37.63, 36.79, 37.09, 37.99, 36.74, 38.190000000000005, 37.22, 37.669999999999995, 38.269999999999996, 38.06, 37.32, 37.32]

densenet121_K100_train = [31.630000000000003, 53.266000000000005, 60.397999999999996, 70.016, 75.398, 78.072, 81.842, 85.196, 87.972, 90.204, 92.458, 94.988, 96.598, 96.958, 98.624, 99.368, 99.812, 99.912, 99.91799999999999, 99.924]
densenet121_K100_test = [26.200000000000003, 45.300000000000004, 50.68, 56.66, 59.199999999999996, 59.050000000000004, 60.85, 61.94, 62.21, 62.18, 62.18, 62.43, 64.27000000000001, 63.36000000000001, 63.36000000000001, 64.72, 65.8, 65.81, 66.5, 66.71000000000001]

resnext50_K100_train = [26.651999999999997, 41.108, 60.68, 72.372, 76.64, 80.866, 84.04, 86.17, 89.30799999999999, 91.532, 93.67999999999999, 95.706, 96.718, 98.116, 99.252, 99.622, 99.848, 99.914, 99.94, 99.924]
resnext50_K100_test = [24.759999999999998, 37.82, 54.1, 60.47, 61.129999999999995, 62.1, 63.029999999999994, 63.029999999999994, 63.14999999999999, 62.99, 64.34, 65.27, 65.29, 65.73, 67.2, 67.45, 67.93, 68.78, 68.61, 68.71000000000001]

# %%
resnet18_K200_train = [7.627000000000001, 22.18, 32.474, 39.109, 46.345, 54.82, 60.893, 67.53099999999999, 74.122, 79.55600000000001, 85.076, 89.679, 93.94500000000001, 97.334, 99.051, 99.586, 99.801, 99.861, 99.875, 99.868]
resnet18_K200_test= [2.65, 6.15, 8.61, 9.53, 10.68, 11.85, 12.64, 14.06, 14.69, 15.52, 15.67, 16.259999999999998, 16.75, 17.45, 18.13, 18.360000000000003, 18.740000000000002, 18.87, 19.09, 19.06]

densenet121_K200_train = [21.439, 34.835, 42.66, 48.335, 52.969, 56.289, 61.028000000000006, 63.037, 66.522, 69.964, 74.504, 78.655, 83.1, 88.347, 93.356, 96.859, 99.039, 99.71900000000001, 99.833, 99.849]
densenet121_K200_test = [6.78, 9.6, 11.01, 11.66, 12.520000000000001, 12.770000000000001, 13.68, 14.08, 14.499999999999998, 14.530000000000001, 15.5, 16.520000000000003, 17.37, 17.77, 18.14, 19.37, 19.78, 20.5, 20.78, 20.93]

resnext50_K200_train = [16.023, 32.999, 40.864, 46.739000000000004, 53.832, 58.489999999999995, 62.312999999999995, 66.066, 69.905, 74.118, 78.688, 83.965, 88.58500000000001, 93.75099999999999, 97.88799999999999, 99.611, 99.837, 99.925, 99.955, 99.937]
resnext50_K200_test = [4.8500000000000005, 7.82, 8.469999999999999, 10.03, 10.780000000000001, 11.899999999999999, 11.76, 12.44, 13.309999999999999, 13.26, 13.900000000000002, 14.62, 15.14, 15.879999999999999, 17.34, 18.67, 18.77, 19.5, 19.79, 19.8]

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,200,10) +9)
plt.plot(epochs, resnet18_K100_train_tau1, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize, markevery=markevery)
plt.plot(epochs, resnet18_K100_train, color = "C3" , linewidth=5, alpha=1, marker = "X", markersize = markersize, markevery=markevery)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'NCC Acc (Train)', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(20,120, 20), fontsize=fontsize)

plt.legend([r'$\tau$ = 1 ', r'$\tau$ = 1 / 7' ], fontsize=fontsize, loc='lower right')

plt.savefig(f"{save_path}/NCC_diff_tau.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,200,10) +9)
plt.plot(epochs, resnet18_K100_train, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize, markevery=markevery)
plt.plot(epochs, densenet121_K100_train, color = "C1" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_K100_train, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize , markevery=markevery)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'NCC Acc (Train)', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(20,120, 20), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='lower right')

plt.savefig(f"{save_path}/CIFAR100_NCC_train.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,200,10) +9)
plt.plot(epochs, resnet18_K100_test, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize, markevery=markevery )
plt.plot(epochs, densenet121_K100_test, color = "C1" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery )
plt.plot(epochs, resnext50_K100_test, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize, markevery=markevery )


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'NCC Acc (Test)', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(20,80, 10), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='lower right')

plt.savefig(f"{save_path}/CIFAR100_NCC_test.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,200,10) +9)
plt.plot(epochs, resnet18_K200_train, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize, markevery=markevery)
plt.plot(epochs, densenet121_K200_train, color = "C1" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_K200_train, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'NCC Acc (Train)', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,120, 20), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='lower right')

plt.savefig(f"{save_path}/TinyImagenet_NCC_train.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,200,10) +9)
plt.plot(epochs, resnet18_K200_test, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize, markevery=markevery)
plt.plot(epochs, densenet121_K200_test, color = "C1" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_K200_test, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'NCC Acc (Test)', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,30, 5), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='lower right')

plt.savefig(f"{save_path}/TinyImagenet_NCC_test.png", dpi = 600,bbox_inches='tight')
plt.show()
