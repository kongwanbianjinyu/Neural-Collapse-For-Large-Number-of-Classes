# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
import os
save_path = "./images/GNC"
#os.mkdir(save_path)

# %% [markdown]
# # CIFAR100

# %% [markdown]
# ## d = 10, K = 100

# %%
hardmax_d10 = 0.61416

# %%
#resnet18_d10_K100_tau7_NC1 = [0.24098304748535157, 0.07555981159210205, 0.04917743682861328, 0.03560440301895142, 0.028600494861602783, 0.025940165519714356, 0.022149641513824463, 0.020787878036499022, 0.020372023582458498, 0.015410051345825196, 0.016019454002380373, 0.013865698575973511, 0.012662781476974487, 0.009410488605499267, 0.00950671374797821, 0.008335084319114686, 0.007678647041320801, 0.007302854061126709, 0.007144248485565186, 0.00710833489894867]
resnet18_d10_K100_tau10_NC1 = [6.71779541015625, 0.20837697982788086, 0.10875858306884766, 0.06395156860351563, 0.05152465343475342, 0.042637262344360355, 0.038125240802764894, 0.03520485401153564, 0.033402509689331054, 0.029707000255584717, 0.025580499172210693, 0.025228753089904785, 0.023526797294616698, 0.02090320110321045, 0.01735532522201538, 0.014764817953109742, 0.01319719672203064, 0.012495384216308594, 0.01164563775062561, 0.011263720989227295, 0.011204005479812621]
densenet121_d10_K100_tau10_NC1 = [2.240771942138672, 0.1859836196899414, 0.0864271068572998, 0.076804838180542, 0.05577846527099609, 0.04652255535125732, 0.04403674125671387, 0.0406699800491333, 0.03679234743118286, 0.03281412124633789, 0.03374310493469238, 0.032580928802490236, 0.029191725254058838, 0.024695820808410644, 0.02567093849182129, 0.022776319980621337, 0.02077303647994995, 0.01875596046447754, 0.019487318992614747, 0.01883270025253296, 0.01776098966598511]
#resnext50_d10_K100_tau7_NC1 = [0.4404396820068359, 0.13768769264221192, 0.05645134449005127, 0.039698705673217774, 0.031217329502105713, 0.02940701484680176, 0.025804193019866944, 0.023279500007629395, 0.022056741714477537, 0.018795523643493652, 0.0171324360370636, 0.01574073076248169, 0.016370983123779298, 0.013336553573608398, 0.013106101751327514, 0.013349423408508301, 0.011953403949737549, 0.011866947412490845, 0.011701228618621827, 0.011607286930084228]
resnext50_d10_K100_tau10_NC1 = [21.5593798828125, 0.17422716140747072, 0.1118526554107666, 0.060569138526916505, 0.045726962089538574, 0.04106344699859619, 0.03573162078857422, 0.032128870487213135, 0.03095073938369751, 0.029562411308288575, 0.02716336965560913, 0.023107993602752685, 0.020250298976898194, 0.01893558621406555, 0.017023993730545042, 0.014482517242431641, 0.013615306615829468, 0.013017020225524902, 0.012471604347229003, 0.012258986234664917, 0.011931746006011964]

# %%
#resnet18_d10_K100_tau7_NC2 = [0.11914414167404175, 0.13595986366271973, 0.15793490409851074, 0.212699294090271, 0.2512003779411316, 0.28811365365982056, 0.32360637187957764, 0.3529667258262634, 0.38225501775741577, 0.43139806389808655, 0.4570697247982025, 0.46712419390678406, 0.5064361095428467, 0.5375078916549683, 0.5472599267959595, 0.5635146498680115, 0.5714283585548401, 0.5763210654258728, 0.5785059928894043, 0.579075038433075]
resnet18_d10_K100_tau10_NC2 = [0,0.14772304892539978, 0.13183987140655518, 0.20695674419403076, 0.23771655559539795, 0.2618247866630554, 0.31200283765792847, 0.3460766077041626, 0.3422800898551941, 0.3879483938217163, 0.4324781894683838, 0.43182387948036194, 0.4822385013103485, 0.5052399635314941, 0.5409297943115234, 0.5401362180709839, 0.5492522716522217, 0.5643514394760132, 0.5680209398269653, 0.5706021785736084, 0.5709181427955627]
densenet121_d10_K100_tau10_NC2 = [0,0.14115113019943237, 0.13653725385665894, 0.1841006875038147, 0.27320152521133423, 0.2771228551864624, 0.34330862760543823, 0.3745993971824646, 0.42204928398132324, 0.4098396301269531, 0.45986464619636536, 0.4599880278110504, 0.5023130178451538, 0.4996148347854614, 0.5369951725006104, 0.5437429547309875, 0.569054365158081, 0.5742800831794739, 0.5774627923965454, 0.5779690742492676, 0.5780000686645508]
#resnext50_d10_K100_tau7_NC2 = [0.006817221641540527, 0.11066186428070068, 0.15318667888641357, 0.20991277694702148, 0.2804182767868042, 0.33535492420196533, 0.3785228729248047, 0.4127490520477295, 0.4229544997215271, 0.4838508069515228, 0.4999587833881378, 0.5250324010848999, 0.5393736362457275, 0.5640915632247925, 0.5652167797088623, 0.5683859586715698, 0.5707342028617859, 0.5734617114067078, 0.5744823217391968, 0.5746410489082336]
resnext50_d10_K100_tau10_NC2 = [0,0.15322476625442505, 0.20340538024902344, 0.2246701717376709, 0.2528693675994873, 0.3015352487564087, 0.3281797766685486, 0.3735243082046509, 0.4296475052833557, 0.43659064173698425, 0.4550734758377075, 0.4722258746623993, 0.5251030921936035, 0.5442517995834351, 0.5481851100921631, 0.5760864019393921, 0.5834272503852844, 0.5883991122245789, 0.5900372862815857, 0.590226411819458, 0.5903419852256775]

# %%
#resnet18_d10_K100_tau7_NC3 = [0.1642065477371216, 0.027602811455726625, 0.018162418007850647, 0.011570332050323486, 0.009744243025779723, 0.008989145755767822, 0.0068679523468017575, 0.006492125988006592, 0.005042880177497864, 0.003181108832359314, 0.003007180690765381, 0.002505033016204834, 0.001940011978149414, 0.0012378966808319091, 0.0009900540113449096, 0.0007258081436157227, 0.0006103402376174926, 0.0004948490858078003, 0.00044759929180145265, 0.0004588043689727783]
resnet18_d10_K100_tau10_NC3 = [0.9985571053996682, 0.17059521675109862, 0.06634086668491364, 0.03337994158267975, 0.026413338780403136, 0.019711741209030152, 0.016477108597755433, 0.015955109596252442, 0.012355849742889405, 0.012733898162841796, 0.008733851313591003, 0.009312123656272889, 0.007347624897956848, 0.005690238475799561, 0.004021168351173401, 0.0027658021450042724, 0.0019215625524520875, 0.0013128548860549926, 0.0010767561197280884, 0.0008863735198974609, 0.000917670726776123]
densenet121_d10_K100_tau10_NC3 = [0.9699598762020468, 0.12600363194942474, 0.05577582597732544, 0.041856619715690616, 0.02554086923599243, 0.02204545557498932, 0.01904155969619751, 0.01801810383796692, 0.01665169358253479, 0.013650186657905579, 0.013259698152542115, 0.010508695244789123, 0.00923206627368927, 0.006839830875396729, 0.00612600028514862, 0.00531775176525116, 0.0040911978483200075, 0.0023216861486434937, 0.0022818821668624876, 0.0021409016847610475, 0.001832793354988098]
resnext50_d10_K100_tau7_NC3 = [0.45214021354913714, 0.06877696990966797, 0.020534499287605285, 0.013588441014289855, 0.010467312932014465, 0.007733142375946045, 0.008045522570610046, 0.0062336111068725586, 0.0055098867416381835, 0.004019929766654968, 0.0030298662185668946, 0.0029022181034088134, 0.002623618245124817, 0.00149053692817688, 0.0012225234508514405, 0.00112967848777771, 0.0009349590539932251, 0.000843927264213562, 0.0007098406553268432, 0.0007733559608459473]
resnext50_d10_K100_tau10_NC3 = [1.0084751142561437, 0.14539608597755432, 0.07354141354560852, 0.03413329303264618, 0.02326982796192169, 0.018893749117851258, 0.015769511461257935, 0.012090038657188416, 0.013014279007911682, 0.01158134162425995, 0.009183613061904907, 0.007951357960700988, 0.006167389154434204, 0.005450574159622193, 0.003994190692901611, 0.0024122142791748046, 0.0018615406751632691, 0.001348189115524292, 0.0010404330492019653, 0.0010087442398071288, 0.0009778565168380737]

# %%
#resnet18_d10_K100_tau7_NC2 = [0,0.11914414167404175, 0.13595986366271973, 0.15793490409851074, 0.212699294090271, 0.2512003779411316, 0.28811365365982056, 0.32360637187957764, 0.3529667258262634, 0.38225501775741577, 0.43139806389808655, 0.4570697247982025, 0.46712419390678406, 0.5064361095428467, 0.5375078916549683, 0.5472599267959595, 0.5635146498680115, 0.5714283585548401, 0.5763210654258728, 0.5785059928894043, 0.579075038433075]
#resnet34_d10 = [0,0.01512688398361206, 0.14738744497299194, 0.17746514081954956, 0.22075432538986206, 0.2578777074813843, 0.3116235136985779, 0.3314586877822876, 0.380354642868042, 0.38397926092147827, 0.4298248887062073, 0.45914196968078613, 0.4637475609779358, 0.5133923292160034, 0.5281440615653992, 0.5554315447807312, 0.5735517144203186, 0.5775129795074463, 0.5757205486297607, 0.5743823051452637, 0.5742940306663513]
#resnet50_d10 = [0,0.021495163440704346, 0.12568330764770508, 0.12847307324409485, 0.16447919607162476, 0.17202532291412354, 0.1903192400932312, 0.18731170892715454, 0.23529267311096191, 0.29358959197998047, 0.3658749461174011, 0.36492443084716797, 0.40723878145217896, 0.46261361241340637, 0.49269434809684753, 0.5429055690765381, 0.5612927675247192, 0.5662014484405518, 0.5696632862091064, 0.5706405639648438, 0.5707273483276367]
#resnext50_d10 = [0,0.006817221641540527, 0.11066186428070068, 0.15318667888641357, 0.20991277694702148, 0.2804182767868042, 0.33535492420196533, 0.3785228729248047, 0.4127490520477295, 0.4229544997215271, 0.4838508069515228, 0.4999587833881378, 0.5250324010848999, 0.5393736362457275, 0.5640915632247925, 0.5652167797088623, 0.5683859586715698, 0.5707342028617859, 0.5734617114067078, 0.5744823217391968, 0.5746410489082336]
#densenet121_d10 = [0,0.14115113019943237, 0.13653725385665894, 0.1841006875038147, 0.27320152521133423, 0.2771228551864624, 0.34330862760543823, 0.3745993971824646, 0.42204928398132324, 0.4098396301269531, 0.45986464619636536, 0.4599880278110504, 0.5023130178451538, 0.4996148347854614, 0.5369951725006104, 0.5437429547309875, 0.569054365158081, 0.5742800831794739, 0.5774627923965454, 0.5779690742492676, 0.5780000686645508]
#inceptionv3_d10 = [0,0.1748570203781128, 0.13335579633712769, 0.16968107223510742, 0.23499053716659546, 0.26783227920532227, 0.34524792432785034, 0.3767242729663849, 0.44315990805625916, 0.48032107949256897, 0.4760327637195587, 0.4880771040916443, 0.5321823358535767, 0.5305525064468384, 0.5505688190460205, 0.5672261714935303, 0.5666871070861816, 0.5716077089309692, 0.5745863914489746, 0.5752952098846436, 0.5754972696304321]
#mobilenet_d10 = [0,0.1661311388015747, 0.15146702527999878, 0.17135947942733765, 0.20140832662582397, 0.1943725347518921, 0.24313578009605408, 0.27022644877433777, 0.31061816215515137, 0.3407774269580841, 0.37722456455230713, 0.40735703706741333, 0.44779643416404724, 0.473030149936676, 0.5082547664642334, 0.5281800627708435, 0.5425753593444824, 0.5514835119247437, 0.5554534196853638, 0.558051586151123, 0.5581990480422974]

# %%
#ViT = [0.23408037424087524, 0.18751227855682373, 0.13173270225524902, 0.12283837795257568, 0.15647631883621216, 0.15479952096939087, 0.13545137643814087, 0.1437353491783142, 0.143419086933136, 0.12717938423156738, 0.13719278573989868, 0.1175503134727478, 0.14815080165863037, 0.16778510808944702, 0.1703183650970459, 0.19293749332427979, 0.15714794397354126, 0.17590707540512085, 0.2009168267250061, 0.18520617485046387, 0.18083679676055908, 0.23345720767974854, 0.22905874252319336, 0.23445826768875122, 0.25357937812805176, 0.2715380787849426, 0.27270519733428955, 0.29740768671035767, 0.31914782524108887, 0.3268442153930664, 0.3355657458305359, 0.35403305292129517, 0.36185765266418457, 0.3648691773414612, 0.3682490587234497, 0.37424778938293457, 0.3758028745651245, 0.3743671178817749, 0.3745344877243042, 0.3749030828475952]
#plt.plot(ViT)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,210,10))
plt.plot(epochs, resnet18_d10_K100_tau10_NC1, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet121_d10_K100_tau10_NC1, color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d10_K100_tau10_NC1, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_1$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,30, 5), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='upper right')

plt.savefig(f"{save_path}/NC1_d10_K100.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,210,10))
plt.plot(epochs, resnet18_d10_K100_tau10_NC2, color = "C0" , linewidth=5, alpha=1,marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet121_d10_K100_tau10_NC2, color = "C1" , linewidth=5, alpha=1,marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d10_K100_tau10_NC2, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)

plt.axhline(y = hardmax_d10, linestyle = "--",color = 'k', linewidth =5)

plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_2$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,0.8, 0.1), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50',"Optimal"], fontsize=fontsize, loc='lower right')

plt.savefig(f"{save_path}/NC2_d10_K100.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,210,10))
plt.plot(epochs, resnet18_d10_K100_tau10_NC3, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet121_d10_K100_tau10_NC3, color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d10_K100_tau10_NC3, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery)

plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_3$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,1.2, 0.2), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='upper right')

plt.savefig(f"{save_path}/NC3_d10_K100.png", dpi = 600,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## d = 20, K = 100

# %%
hardmax_d20 = 0.8124

# %%
resnet18_d20 = [0.30641868710517883, 0.3492225110530853, 0.4565284550189972, 0.4988326132297516, 0.5289452075958252, 0.5952977538108826, 0.6154927015304565, 0.6254644393920898, 0.6246826648712158, 0.6690551042556763, 0.6963924169540405, 0.705398678779602, 0.7134060859680176, 0.7297746539115906, 0.7413293123245239, 0.7533260583877563, 0.7596906423568726, 0.7623288035392761, 0.7633953094482422, 0.7635708451271057]
resnet50_d20 = [0.03324693441390991, 0.22005122900009155, 0.26101428270339966, 0.36082765460014343, 0.4339067041873932, 0.42883172631263733, 0.509803056716919, 0.5776621103286743, 0.6063778400421143, 0.6352895498275757, 0.40520918369293213, 0.5476025342941284, 0.6310628652572632, 0.6698309183120728, 0.6919864416122437, 0.7070437669754028, 0.7199211120605469, 0.7254494428634644, 0.7267457246780396, 0.7269671559333801]
resnext50_d20 = [0.030749022960662842, 0.06520146131515503, 0.2618984282016754, 0.3884679079055786, 0.4911052882671356, 0.5397756099700928, 0.5854874849319458, 0.6101939678192139, 0.6481364965438843, 0.6699917912483215, 0.6902737021446228, 0.7098631262779236, 0.723111629486084, 0.7399864196777344, 0.7521494030952454, 0.7607854008674622, 0.7628240585327148, 0.7647316455841064, 0.7655575275421143, 0.7656239867210388]

# %% [markdown]
# ## d = 30, K = 100

# %%
hardmax_d30 = 0.8886
epochs = list(np.arange(0,200,10) + 1)

# %%
resnet18_d30 =  [0.4127727150917053, 0.3817429542541504, 0.48133718967437744, 0.5946977138519287, 0.6382533311843872, 0.6816555261611938, 0.6839237213134766, 0.7294677495956421, 0.7427137494087219, 0.7520143985748291, 0.7747085094451904, 0.7923150658607483, 0.8040810227394104, 0.8195751309394836, 0.8255898356437683, 0.8295300602912903, 0.8309535980224609, 0.8315133452415466, 0.8316597938537598, 0.8317005634307861]
#resnext50_d30 =

# %%
hardmax_d10 = 0.61416
hardmax_d20 = 0.8124
hardmax_d30 = 0.8886
#epochs = list(np.arange(0,200,10) + 1)

# %%
resnet18_d10 = [0,0.14772304892539978, 0.13183987140655518, 0.20695674419403076, 0.23771655559539795, 0.2618247866630554, 0.31200283765792847, 0.3460766077041626, 0.3422800898551941, 0.3879483938217163, 0.4324781894683838, 0.43182387948036194, 0.4822385013103485, 0.5052399635314941, 0.5409297943115234, 0.5401362180709839, 0.5492522716522217, 0.5643514394760132, 0.5680209398269653, 0.5706021785736084, 0.5709181427955627]
resnet18_d20 = [0,0.30641868710517883, 0.3492225110530853, 0.4565284550189972, 0.4988326132297516, 0.5289452075958252, 0.5952977538108826, 0.6154927015304565, 0.6254644393920898, 0.6246826648712158, 0.6690551042556763, 0.6963924169540405, 0.705398678779602, 0.7134060859680176, 0.7297746539115906, 0.7413293123245239, 0.7533260583877563, 0.7596906423568726, 0.7623288035392761, 0.7633953094482422, 0.7635708451271057]
resnet18_d30 =  [0,0.4127727150917053, 0.3817429542541504, 0.48133718967437744, 0.5946977138519287, 0.6382533311843872, 0.6816555261611938, 0.6839237213134766, 0.7294677495956421, 0.7427137494087219, 0.7520143985748291, 0.7747085094451904, 0.7923150658607483, 0.8040810227394104, 0.8195751309394836, 0.8255898356437683, 0.8295300602912903, 0.8309535980224609, 0.8315133452415466, 0.8316597938537598, 0.8317005634307861]

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
fontsize = 30
markersize = 15
markevery = 5

epochs = list(np.arange(0,210,10))
plt.plot(epochs, resnet18_d10, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery )
plt.plot(epochs, resnet18_d20, color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery )
plt.plot(epochs, resnet18_d30, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery )


plt.axhline(y = hardmax_d10, linestyle = "--",color = 'C0', linewidth =5)
plt.axhline(y = hardmax_d20, linestyle = "--",color = 'C1', linewidth =5)
plt.axhline(y = hardmax_d30, linestyle = "--",color = 'C2', linewidth =5)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_2$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,1.2, 0.2), fontsize=fontsize)

plt.legend([r'$d = 10$', r'$d = 20$', r'$d = 30$'], fontsize=fontsize, loc='lower right')


plt.savefig(f"{save_path}/resnet18.png", dpi = 600,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Tiny imagenet Classification

# %% [markdown]
# ## d = 10, K = 200

# %%
hardmax_d10_K200 = 0.5052

# %%
resnet18_d10_K200_NC1 = [2.3273292541503907, 0.2575183296203613, 0.08816689491271973, 0.05630042552947998, 0.04713673114776611, 0.0395685076713562, 0.034764626026153565, 0.03177780628204346, 0.02776122570037842, 0.024000773429870604, 0.02278684139251709, 0.01979228377342224, 0.0178315806388855, 0.01586175203323364, 0.013428714275360108, 0.011387526988983154, 0.010403789281845092, 0.009750319719314575, 0.009545806050300597, 0.0094099760055542, 0.009392959475517272]
densenet_d10_K200_NC1 = [0.95315673828125, 0.10931123733520508, 0.06219682216644287, 0.0473889684677124, 0.039818925857543944, 0.03483888149261474, 0.03203898429870605, 0.0283014178276062, 0.02697158098220825, 0.02419907569885254, 0.022921998500823975, 0.019383188486099243, 0.01759274959564209, 0.014541997909545898, 0.01278501033782959, 0.010575125217437744, 0.008542388081550598, 0.007137400507926941, 0.006560635566711426, 0.006098634600639343, 0.005924400091171265]
resnext50_d10_K200_NC1 = [5.758613891601563, 0.10668863296508789, 0.05057699680328369, 0.04483719348907471, 0.04013319492340088, 0.03634411811828613, 0.033931732177734375, 0.03257302761077881, 0.027403204441070556, 0.02627338171005249, 0.024138820171356202, 0.021820106506347657, 0.01871628999710083, 0.017279071807861326, 0.014863147735595703, 0.012328696250915528, 0.009418481588363647, 0.008823328614234925, 0.008028197288513183, 0.00789657175540924, 0.007846704125404358]

# %%
#resnet18_d10_K200 = [0.12356686592102051, 0.10035449266433716, 0.07579392194747925, 0.08155542612075806, 0.110287606716156, 0.12877529859542847, 0.18956321477890015, 0.2117551565170288, 0.22462743520736694, 0.26444369554519653, 0.29344260692596436, 0.3304963707923889, 0.37422966957092285, 0.37918221950531006, 0.39435726404190063, 0.39850926399230957, 0.39934074878692627, 0.4049875736236572, 0.40646880865097046, 0.40652191638946533]
resnet18_d10_K200_NC2 = [0,0.14005309343338013, 0.10051095485687256, 0.12244230508804321, 0.15488982200622559, 0.1766115427017212, 0.21769064664840698, 0.22326332330703735, 0.25015681982040405, 0.25725430250167847, 0.2752946615219116, 0.3057990074157715, 0.31184571981430054, 0.3856598734855652, 0.4101385474205017, 0.43502670526504517, 0.46247613430023193, 0.4672544598579407, 0.47060543298721313, 0.47244322299957275, 0.4727408289909363]
densenet_d10_K200_NC2 = [0,0.1180109977722168, 0.08482557535171509, 0.13190186023712158, 0.14598244428634644, 0.10769158601760864, 0.1634504795074463, 0.19189083576202393, 0.18952780961990356, 0.18556159734725952, 0.23445266485214233, 0.2519683837890625, 0.2713480591773987, 0.3151439428329468, 0.33144617080688477, 0.37806010246276855, 0.4011456370353699, 0.4285779595375061, 0.44529247283935547, 0.4500625729560852, 0.45116621255874634]
resnext50_d10_K200_NC2 = [0,0.12901198863983154, 0.11975884437561035, 0.1305028796195984, 0.1475886106491089, 0.16878187656402588, 0.19032859802246094, 0.22803562879562378, 0.22590798139572144, 0.2716359496116638, 0.29565685987472534, 0.3413900136947632, 0.38252508640289307, 0.40707099437713623, 0.43904024362564087, 0.4623340368270874, 0.47227370738983154, 0.48012053966522217, 0.4814167022705078, 0.4825094938278198, 0.4826623201370239]
#[0.09036600589752197, 0.09918045997619629, 0.09526801109313965, 0.13946843147277832, 0.15203869342803955, 0.15839821100234985, 0.14336079359054565, 0.1901896595954895, 0.20581161975860596, 0.217454195022583, 0.22635328769683838, 0.24392157793045044, 0.2796064019203186, 0.342021644115448, 0.38445377349853516, 0.4144917130470276, 0.41776758432388306, 0.42247259616851807, 0.424177348613739, 0.4243727922439575]

# %%
resnet18_d10_K200_NC3 = [1.0154281463846564, 0.42899827774614097, 0.3313507442176342, 0.25789420664310453, 0.18859920606017114, 0.12740888491272925, 0.08175536304712296, 0.07960161238908768, 0.0799050885438919, 0.0668699786067009, 0.045971803069114685, 0.027451286911964416, 0.014104786217212678, 0.008798021972179413, 0.006368160843849182, 0.004687827229499817, 0.0035634458065032957, 0.003166690468788147, 0.0029564547538757325, 0.0027869632840156556, 0.002766370177268982]
densenet_d10_K200_NC3 = [0.9932283238321543, 0.15629058182239533, 0.09250761985778809, 0.06356219708919525, 0.04810651123523712, 0.037540676295757296, 0.02907791703939438, 0.02331714391708374, 0.021575553715229033, 0.018831916451454163, 0.01651048004627228, 0.013516467213630676, 0.010699296891689301, 0.00758040577173233, 0.006806792318820953, 0.004780036509037018, 0.0031558328866958616, 0.0019294467568397521, 0.0014419445395469665, 0.0011648133397102356, 0.0010426065325737]
resnext50_d10_K200_NC3 = [1.0152350958995522, 0.46846692775841803, 0.33382075782865284, 0.21403396859765053, 0.11482122033834458, 0.16178859859704972, 0.1627539536356926, 0.15109955996274949, 0.13723608165979384, 0.1194968095421791, 0.09765061378479004, 0.07701453179121018, 0.05021790534257889, 0.027149127423763277, 0.011679036617279053, 0.0069887319207191465, 0.0045312756299972536, 0.003638801872730255, 0.0025385087728500367, 0.002255803644657135, 0.0022024878859519957]

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

epochs = list(np.arange(0,210,10))
plt.plot(epochs, resnet18_d10_K200_NC1, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet_d10_K200_NC1 , color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d10_K200_NC1, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery)

plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_1$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,8, 2), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='upper right')


plt.savefig(f"{save_path}/NC1_d10_K200.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

epochs = list(np.arange(0,210,10))
plt.plot(epochs, resnet18_d10_K200_NC2, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet_d10_K200_NC2 , color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d10_K200_NC2, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery)


plt.axhline(y = hardmax_d10_K200, linestyle = "--",color = 'k', linewidth =5)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_2$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,0.7, 0.1), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50',"optimal"], fontsize=fontsize, loc='lower right')


plt.savefig(f"{save_path}/NC2_d10_K200.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

epochs = list(np.arange(0,210,10) )
plt.plot(epochs, resnet18_d10_K200_NC3, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet_d10_K200_NC3 , color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d10_K200_NC3, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery)

plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_3$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,1.2, 0.2), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50',"Optimal"], fontsize=fontsize, loc='upper right')


plt.savefig(f"{save_path}/NC3_d10_K200.png", dpi = 600,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## d = 20, K = 200

# %%
hardmax_d20_K200 = 0.7211

# %%
resnet18_d20_K200 = [0.2979546785354614, 0.257148414850235, 0.27264299988746643, 0.25778087973594666, 0.25654321908950806, 0.26050812005996704, 0.2976415157318115, 0.3138447403907776, 0.34379032254219055, 0.4191522002220154, 0.47458645701408386, 0.5223175287246704, 0.5460553765296936, 0.5576980710029602, 0.5673967599868774, 0.5834972262382507, 0.5857075452804565, 0.5865451693534851, 0.5871926546096802, 0.5872253179550171]

# %% [markdown]
# ## d = 30, K = 200

# %%
hardmax_d30_K200 = 0.8053

# %%
resnet18_d30_K200 = [0.32717251777648926, 0.341002881526947, 0.3484872579574585, 0.38323116302490234, 0.3986815810203552, 0.43991097807884216, 0.46572697162628174, 0.5241681337356567, 0.585334062576294, 0.6047853231430054, 0.6095740795135498, 0.6271896362304688, 0.6454577445983887, 0.6428085565567017, 0.6547492742538452, 0.6649367809295654, 0.6695337295532227, 0.671932578086853, 0.6727199554443359, 0.672809362411499]

# %% [markdown]
# # BUPT-CBFace-50 dataset

# %%
hardmax_d512_K10000 = 1- 0.20341322 # 0.8627
epochs = list(np.arange(0,210,10) )

# %%
resnet18_d512_K10000_tau50 = [0,0.5562231540679932, 0.609129786491394, 0.6400052309036255, 0.6466154456138611, 0.6496230363845825, 0.6604341268539429, 0.6675142049789429, 0.6738123893737793, 0.6719965934753418, 0.6777924299240112, 0.6786934733390808, 0.6811650991439819, 0.6936965584754944, 0.6927920579910278, 0.6923761963844299, 0.6941293478012085, 0.6950554847717285, 0.6951051354408264, 0.6950998306274414, 0.6951504349708557]

# %%
resnet18_d512_K10000_tau20 = [0,0.5129669904708862, 0.5579818487167358, 0.5588724613189697, 0.5634738802909851, 0.5743286609649658, 0.5628681778907776, 0.5773504376411438, 0.5826061964035034, 0.5872348546981812, 0.5898733735084534, 0.5966048836708069, 0.5940200090408325, 0.5939484238624573, 0.6003918051719666, 0.6022721529006958, 0.6104801893234253, 0.6316142082214355, 0.6396185159683228, 0.640958309173584, 0.6410599946975708]
resnet18_d512_K10000_tau10 = [0,0.2645895779132843, 0.278078556060791, 0.28748270869255066, 0.2927219271659851, 0.28988587856292725, 0.28178223967552185, 0.2641117572784424, 0.2651897668838501, 0.2405078113079071, 0.26915404200553894, 0.2793099284172058, 0.27341416478157043, 0.24715131521224976, 0.26773008704185486, 0.28030654788017273, 0.27349480986595154, 0.31782248616218567, 0.35421112179756165, 0.389785498380661, 0.3993683457374573]
densenet121_d512_K10000_tau20 = [0,0.5413527488708496, 0.5660926103591919, 0.5826917886734009, 0.5897939205169678, 0.594258189201355, 0.6013081669807434, 0.6023528575897217, 0.603929877281189, 0.6048404574394226, 0.6095994114875793, 0.6129058599472046, 0.5985283255577087, 0.6116405725479126, 0.6152098178863525, 0.6182668209075928, 0.6312952637672424, 0.29573339223861694, 0.2991674244403839, 0.30247536301612854, 0.3007467985153198]
densenet121_d512_K10000_tau50 = [0,0.5903782844543457, 0.6161878705024719, 0.6511965990066528, 0.6616511344909668, 0.6636433601379395, 0.664902925491333, 0.6793237924575806, 0.6738348007202148, 0.6750798225402832, 0.669625997543335, 0.6910913586616516, 0.6897501349449158, 0.6893725991249084, 0.6941129565238953, 0.6946148872375488, 0.7048146724700928, 0.7023031115531921, 0.7049750685691833, 0.7046186923980713, 0.704341471195221]
resnext50_d512_K10000_tau50 = [0,0.5605893135070801, 0.6372479200363159, 0.6527578234672546, 0.6667152643203735, 0.6729974746704102, 0.6804090738296509, 0.6869168877601624, 0.6930785775184631, 0.6894817352294922, 0.6908048391342163, 0.6946964263916016, 0.696500301361084, 0.7079294323921204, 0.7007205486297607, 0.7048148512840271, 0.7042831182479858, 0.7134119272232056, 0.715117335319519, 0.7154541611671448, 0.7155265212059021]

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

plt.plot(epochs, resnet18_d512_K10000_tau50, color = "C0" , linewidth=5, alpha=1,marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet121_d512_K10000_tau50, color = "C1" , linewidth=5, alpha=1,marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d512_K10000_tau50, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)


plt.axhline(y = hardmax_d512_K10000, linestyle = "--",color = 'k', linewidth =5)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_2$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,0.9, 0.2), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50', "Optimal"], fontsize=fontsize, loc='lower right')
 

plt.savefig(f"{save_path}/NC2_d512_K10000.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

plt.plot(epochs, resnet18_d512_K10000_tau10, color = "C0" , linewidth=5, alpha=1,marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnet18_d512_K10000_tau20, color = "C1" , linewidth=5, alpha=1,marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnet18_d512_K10000_tau50, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)
#plt.plot(epochs, resnext50_d512_K10000_tau50, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize,  markevery=markevery)


plt.axhline(y = hardmax_d512_K10000, linestyle = "--",color = 'k', linewidth =5)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_2$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,0.9, 0.2), fontsize=fontsize)

plt.legend([r'$\tau$ = 1 / 10', r'$\tau$ = 1 / 20', r'$\tau$ = 1 / 50', "Optimal"], fontsize=fontsize, loc='lower right')
 

plt.savefig(f"{save_path}/NC2_d512_K10000_diff_tau.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
hardmax_d2048_K10000 = 1-0.10167998 # 0.9382922649383545 #

# %%
NC2_f2048_K10000 = [0,0.6125417947769165, 0.6462226510047913, 0.6580439209938049, 0.6667835712432861, 0.6627945303916931, 0.6622019410133362, 0.6720173358917236, 0.6704034805297852, 0.6816397905349731, 0.6772557497024536, 0.6926575899124146, 0.6800682544708252, 0.6906836032867432, 0.6975472569465637, 0.6925864219665527, 0.7026994228363037, 0.7011226415634155, 0.702572226524353, 0.7029564380645752, 0.7029402852058411]

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30

plt.plot(epochs, NC2_f2048_K10000, color = "C0" , linewidth=5, alpha=1,marker = "o", markersize = markersize)
#plt.plot(epochs, densenet121_d512_K10000_tau50, color = "C1" , linewidth=5, alpha=1,marker = "X", markersize = markersize)
#plt.plot(epochs, resnext50_d512_K10000_tau50, color = "C2" , linewidth=5, alpha=1,marker = "P", markersize = markersize)


plt.axhline(y = hardmax_d2048_K10000, linestyle = "--",color = 'k', linewidth =5)


plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_2$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,1.0, 0.1), fontsize=fontsize)

plt.legend(['ResNet18', "Optimal"], fontsize=fontsize, loc='lower right')
 

plt.savefig("./images/NC2_d2048_K10000.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
resnet18_d512_K10000_tau50_NC1 =[1.597098828125,0.04267633056640625, 0.048357843017578124, 0.0525287109375, 0.05423182983398438, 0.05511951293945312, 0.05600679321289063, 0.05690144653320312, 0.05962784423828125, 0.05877156982421875, 0.058747705078125, 0.0573953369140625, 0.059767431640625, 0.05904906005859375, 0.05813306274414062, 0.05522064208984375, 0.053271923828125, 0.05305238647460937, 0.0526808349609375, 0.05255323486328125, 0.05251844482421875]
densenet121_d512_K10000_tau50_NC1 = [1.4557025390625, 0.0397603515625, 0.050235379028320315, 0.05413634033203125, 0.05646541748046875, 0.058040838623046875, 0.05890635375976563, 0.05865297241210937, 0.05955594482421875, 0.06070740966796875, 0.0612296630859375, 0.06130174560546875, 0.06187401123046875, 0.06240947875976562, 0.060837261962890625, 0.06080997314453125, 0.06405350952148438, 0.0549149658203125, 0.05501370239257813, 0.05527430419921875, 0.0553244140625]
resnext50_d512_K10000_tau50_NC1 = [2.457847265625, 0.032223361206054686, 0.04699629821777344, 0.05418104858398438, 0.0575686767578125, 0.058824169921875, 0.06325292358398438, 0.0619288330078125, 0.06416499633789062, 0.06593438110351563, 0.06583602294921875, 0.06511488037109375, 0.0653641845703125, 0.06494765625, 0.06538616333007813, 0.06480401000976563, 0.06512596435546875, 0.05941190185546875, 0.0604146728515625, 0.060677215576171874, 0.06126090087890625]

epochs = list(np.arange(0,210,10) )

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

plt.plot(epochs, resnet18_d512_K10000_tau50_NC1, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet121_d512_K10000_tau50_NC1 , color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d512_K10000_tau50_NC1, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery)

plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_1$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,3, 0.5), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='upper right')

plt.savefig(f"{save_path}/NC1_d512_K10000.png", dpi = 600,bbox_inches='tight')
plt.show()

# %%
resnet18_d512_K10000_tau50_NC3 = [1.0010447870713193, 0.19395651037096978, 0.21222139877676963, 0.21827166786193847, 0.2236071098446846, 0.2244945790886879, 0.22447269945144654, 0.22477855167984961, 0.22856576755046845, 0.2231233351290226, 0.22050708858966828, 0.21651729861199856, 0.21331866807341576, 0.20853401211500167, 0.199822762966156, 0.17488343142271043, 0.15596637805104255, 0.15194434629678727, 0.15014825021624564, 0.1495242047727108, 0.1493906934916973]
densenet121_d512_K10000_tau50_NC3 = [1.00096339244002, 0.20873560763001442, 0.22613510887920857, 0.23179891480207443, 0.2369817147910595, 0.23517135192155839, 0.23943258236050605, 0.23807817427814007, 0.23902542298436164, 0.23428046471476555, 0.23562109384536742, 0.2330866767883301, 0.23126912394165994, 0.22623079302310944, 0.21790758562088014, 0.21151198188066483, 0.2390270448833704, 0.16719076165556906, 0.16336152754426003, 0.16129069880843164, 0.16114377393722534]
resnext50_d512_K10000_tau50_NC3 = [0.9997803547384799, 0.19852566375136377, 0.22384490296840667, 0.2331713331222534, 0.2372884942471981, 0.24005636382102966, 0.2381115379333496, 0.23973800892829894, 0.2385274858534336, 0.23696020654439925, 0.23416361931562424, 0.23361835281848908, 0.22712767142653464, 0.22564794622063636, 0.21621628849506377, 0.20894298015832902, 0.21517748073935508, 0.17333624014258384, 0.16116934326291085, 0.15795364748239518, 0.15768481528162956]

epochs = list(np.arange(0,210,10) )

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.grid(True)
markersize = 15
fontsize = 30
markevery = 5

plt.plot(epochs, resnet18_d512_K10000_tau50_NC3, color = "C0" , linewidth=5, alpha=1, marker = "o", markersize = markersize,  markevery=markevery)
plt.plot(epochs, densenet121_d512_K10000_tau50_NC3 , color = "C1" , linewidth=5, alpha=1, marker = "X", markersize = markersize,  markevery=markevery)
plt.plot(epochs, resnext50_d512_K10000_tau50_NC3, color = "C2" , linewidth=5, alpha=1, marker = "P", markersize = markersize,  markevery=markevery)

plt.xlabel('Epochs', fontsize=fontsize)
plt.ylabel(r'$\mathcal{GNC}_3$', fontsize=fontsize)

plt.xticks(np.arange(0, 220, 50), fontsize=fontsize)
plt.yticks(np.arange(0,1.2, 0.2), fontsize=fontsize)

plt.legend(['ResNet18', 'DenseNet121', 'ResNeXt50'], fontsize=fontsize, loc='upper right')


plt.savefig(f"{save_path}/NC3_d512_K10000.png", dpi = 600,bbox_inches='tight')
plt.show()
